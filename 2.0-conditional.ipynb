# %% [markdown]
# ### ✅ Conditional Statements in Python (Simple Explanation)
#
# Conditional statements are used to **make decisions** in Python. They help your program decide what to do **based on conditions** (like if something is true or false).
#
# ---
#
# ### 🔹 1. `if` Statement
#
# Used when you want to do something **only if a condition is true**.
#
# ```python
# age = 18
# if age >= 18:
#     print("You can vote")
# ```
#
# 🟢 Output: `You can vote`
#
# ---
#
# ### 🔹 2. `if-else` Statement
#
# Used when you want to choose **between two options**.
#
# ```python
# age = 16
# if age >= 18:
#     print("You can vote")
# else:
#     print("You cannot vote")
# ```
#
# 🟢 Output: `You cannot vote`
#
# ---
#
# ### 🔹 3. `if-elif-else` Statement
#
# Used when you have **multiple conditions**.
#
# ```python
# marks = 75
#
# if marks >= 90:
#     print("Grade A")
# elif marks >= 60:
#     print("Grade B")
# else:
#     print("Grade C")
# ```
#
# 🟢 Output: `Grade B`
#
# ---
#
# ### 🔹 4. Nested `if`
#
# You can also use an `if` inside another `if`.
#
# ```python
# age = 20
# citizen = True
#
# if age >= 18:
#     if citizen:
#         print("You can vote")
#     else:
#         print("Only citizens can vote")
# ```
#
# 🟢 Output: `You can vote`
#
# ---
#
# ### 🔹 5. Short-hand `if` (One-liner)
#
# Used for **very short conditions**.
#
# ```python
# a = 10
# b = 5
#
# print("a is greater") if a > b else print("b is greater")
# ```
#
# 🟢 Output: `a is greater`
#
# ---
#
# Let me know if you want a revision sheet or quiz for this topic!

# %%
#nested if

num=int(input("enter a number:"))
if num>0:
  print("the number is positive")
  if num%2==0:
    print("number is even")
  else:
    print("number is odd")
elif num==0:
  print("number is neutral")
else:
  print("number is negative")
# Out:
# number is negative

# %%
#leap year using nested 

year=int(input("enter a year:"))

if year%4==0:
  if year%100==0:
    if year%400==0:
      print(year,"is a leap year")
    else:
      print(year,"is not a leap year")
  else:                                          #beacuse of year%100 != 0 then it is a leap year
    print(year,"is a leap year")

else:
  print(year,"is a not leap year")
# Out:
# 7890 is a not leap year

# %%
# #basic calculator:
# firstnumber=int(input("enter a first number: "))
# secondnumber=int(input("enter a second number: "))
# operator=input("enter a operator according to your need(+,-,*,/,%,//,**): ")

# print("your insterting number 1 is :",firstnumber)
# print("your insterting number 2 is :",secondnumber)

# add = firstnumber+secondnumber
# sub=firstnumber-secondnumber
# mult=firstnumber*secondnumber
# mod=firstnumber%secondnumber
# floor=firstnumber//secondnumber
# sqrt=firstnumber**secondnumber


# if operator== "+":
#   print("ADDITION OF INSERTING TWO NUMBER IS :",add)

# elif operator== "-":
#   print("SUBTRACTION OF INSERTING TWO NUMBER IS :",sub)

# elif operator== "*":
#   print("MULTIPLICATION OF INSERTING TWO NUMBER IS :",mult)

# elif operator== "/":
#   if secondnumber!=0:
#     print("DIVISION OF INSERTING TWO NUMBER IS :",firstnumber/secondnumber)
#   else:
#     print("division by zero is not possible")

# elif operator== "%":
#   print("MODULAR OF INSERTING TWO NUMBER IS :",mod)
  
# elif operator== "//":
#   print("FLOOR DIVISION OF INSERTING TWO NUMBER IS :",floor)

# elif operator== "**":
#   print("SQUARE ROOT OF INSERTING TWO NUMBER IS :",sqrt)

# else:
#   print("invalid ")



# Basic calculator:
firstnumber = int(input("Enter the first number: "))
secondnumber = int(input("Enter the second number: "))
operator = input("Enter an operator (+, -, *, /, %, //, **): ")

print("Your inserting number 1 is:", firstnumber)
print("Your inserting number 2 is:", secondnumber)

if operator == "+":
    print("ADDITION OF INSERTING TWO NUMBER IS:", firstnumber + secondnumber)

elif operator == "-":
    print("SUBTRACTION OF INSERTING TWO NUMBER IS:", firstnumber - secondnumber)

elif operator == "*":
    print("MULTIPLICATION OF INSERTING TWO NUMBER IS:", firstnumber * secondnumber)

elif operator == "/":
    if secondnumber != 0:
        print("DIVISION OF INSERTING TWO NUMBER IS:", firstnumber / secondnumber)
    else:
        print("ERROR: Division by zero is not possible.")

elif operator == "%":
    if secondnumber != 0:
        print("MODULUS OF INSERTING TWO NUMBER IS:", firstnumber % secondnumber)
    else:
        print("ERROR: Modulus by zero is not possible.")

elif operator == "//":
    if secondnumber != 0:
        print("FLOOR DIVISION OF INSERTING TWO NUMBER IS:", firstnumber // secondnumber)
    else:
        print("ERROR: Floor division by zero is not possible.")

elif operator == "**":
    print("EXPONENTIATION OF INSERTING TWO NUMBER IS:", firstnumber ** secondnumber)

else:
    print("Invalid operator!")
# Out:
# Your inserting number 1 is: 73
# Your inserting number 2 is: 0
# ERROR: Division by zero is not possible.

# %%
#determine ticket price based on age and student status

age=int(input("enter your age:"))
student=input("if you are student then enter yes otherwise enter no :").lower()

if age<5:
  print("your ticket is free")
elif age <10:
  print("your ticket price is 100rs")
elif age<17:
  if student=="yes":
    print("your ticket price is 150")
  else:
    print("your ticket price is 250")
else:
  print("your ticket price is 450")
# Out:
# your ticket price is 250
